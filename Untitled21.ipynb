# %%
#Write insert(self, data) function that will create a node and insert the node into a BST. #You should write the insert function with iteration. Then Take a list of 12 elements.
#Randomly generate 12 numbers and put them into the list. Then in a loop, use insert function to insert the elements in to a BST
import random
class TreeNode:
    def __init__(self, key):
        self.key = key
        self.left = None
        self.right = None
class BST:
    def __init__(self):
        self.root = None
    def insert(self, data):
        new_node = TreeNode(data)
        if not self.root:
            self.root = new_node
            return
        current = self.root
        while current:
            if data < current.key:
                if current.left:
                    current = current.left
                else:
                    current.left = new_node
                    break
            elif data > current.key:
                if current.right:
                    current = current.right
                else:
                    current.right = new_node
                    break
            else:
                break

def main():
    random_numbers = random.sample(range(1, 100), 12)
    bst = BST()
    for number in random_numbers:
        bst.insert(number)
    print("Inorder Traversal of BST:")
    inorder_traversal(bst.root)
def inorder_traversal(node):
    if node:
        inorder_traversal(node.left)
        print(node.key, end=" ")
        inorder_traversal(node.right)
if __name__ == "__main__":
    main()
# Out:
# Inorder Traversal of BST:
# 5 6 9 13 17 42 43 56 58 65 82 92

# %%
#2. Write insertR(self, data) that will create a node and insert the node into a BST with recursion. You should not use any iteration


import random

class TreeNode:
    def __init__(self, key):
        self.key = key
        self.left = None
        self.right = None

class BST:
    def __init__(self):
        self.root = None

    def insert(self, data):
        new_node = TreeNode(data)
        if not self.root:
            self.root = new_node
            return

        current = self.root
        while current:
            if data < current.key:
                if current.left:
                    current = current.left
                else:
                    current.left = new_node
                    break
            elif data > current.key:
                if current.right:
                    current = current.right
                else:
                    current.right = new_node
                    break
            else:
                break

def main():
    # Generate a list of 12 random numbers
    random_numbers = random.sample(range(1, 100), 12)

    # Create a BST and insert the numbers into it using iteration
    bst = BST()
    for number in random_numbers:
        bst.insert(number)
    print("Inorder Traversal of BST:")
    inorder_traversal(bst.root)
def inorder_traversal(node):
    if node:
        inorder_traversal(node.left)
        print(node.key, end=" ")
        inorder_traversal(node.right)
if __name__ == "__main__":
    main()
# Out:
# Inorder Traversal of BST:
# 8 25 41 45 48 49 80 81 84 85 87 89

# %%
#Write searchR(self, root, data) that will search the data in a BST using recursion

import random
bst = BsTree()
for i in range (0, 12):
  n = random.randint(0,100)
  bst.insert(n)
bst.inorder(bst.root)
data = int(input("Enter the data to search"))
flag =  bst.searchR(bst.root, data)
if flag:
  print(str(data) + " is found")
else:
  print(str(data) + " is not found")
# Out:
# 14
# 15
# 24
# 26
# 37
# 42
# 49
# 59
# 60
# 60
# 85
# 99
# Enter the data to search23
# 23 is not found

# %%
#3Write findMaxR(self, root) that will return the maximum of a BST using recursio

class BST:
    def __init__(self):
        self.root = None

    def insertR(self, data):
        self.root = self._insert(self.root, data)

    def _insert(self, node, data):
        if not node:
            return TreeNode(data)

        if data < node.key:
            node.left = self._insert(node.left, data)
        elif data > node.key:
            node.right = self._insert(node.right, data)

        return node

    def findMaxR(self, root):
        if not root:
            return None

        while root.right:
            root = root.right

        return root.key
    max_value = bst.findMaxR(bst.root)
    print("Maximum value in the BST:", max_value)

if __name__ == "__main__":
    main()
# Out:
# Maximum value in the BST: 95
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-82-c2adaca00453> in <cell line: 32>()
#      31
#      32 if __name__ == "__main__":
# ---> 33     main()
#      34
#      35
#
# <ipython-input-79-4d927fdc1e98> in main()
#      45     bst = BST()
#      46     for number in random_numbers:
# ---> 47         bst.insert(number)
#      48
#      49     # Print the inorder traversal of the BST to verify the insertion
#
# AttributeError: 'BST' object has no attribute 'insert'
