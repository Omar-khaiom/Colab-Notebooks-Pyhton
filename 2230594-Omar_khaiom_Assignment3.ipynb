# %%
# @title If-else

#1-Absolute Value
def absolute_value(n):
    if n < 0:
        return -n
    return n

n = float(input("Enter a number: "))
print("Absolute value of", n, "is", absolute_value(n))

#2_Largest among Two Numbers:
def largest_number(n1, n2):
    if n1 > n2:
        return n1
    return n2

n1 = float(input("Enter the first number: "))
n2 = float(input("Enter the second number: "))
print("Largest number is:", largest_number(n1, n2))

#3-Sign of a Number:
def sign_of_number(n):
    if n == 0:
        return "Zero"
    elif n > 0:
        return "Positive"
    return "Negative"

n = float(input("Enter a number: "))
print("The number is:", sign_of_number(n))

#4-Maximum of Three Numbers:
def maximum_of_three(n1, n2, n3):
    if n1 >= n2 and n1 >= n:
        return n1
    elif n2 >= n1 and n2 >= n3:
        return n2
    return n3

n1 = float(input("Enter the first number: "))
n2 = float(input("Enter the second number: "))
n3 = float(input("Enter the third number: "))
print("Largest number is:", maximum_of_three(n1, n2, n3))

#5-Quadrant Determination:
def determine_quadrant(x, y):
    if x == 0 or y == 0:
        return "None"
    elif x > 0:
        return "Quadrant I" if y > 0 else "Quadrant IV"
    else:
        return "Quadrant II" if y > 0 else "Quadrant III"

x = float(input("Enter the x-coordinate: "))
y = float(input("Enter the y-coordinate: "))
print("Point lies in:", determine_quadrant(x, y))23
# Out:
# Enter a number: 23
# Absolute value of 23.0 is 23.0
# Enter the first number: 23
# Enter the second number: 41
# Largest number is: 41.0
# Enter a number: 3
# The number is: Positive
# Enter the first number: 41
# Enter the second number: 2
# Enter the third number: 23
# Largest number is: 41.0
# Enter the x-coordinate: 3
# Enter the y-coordinate: 4
# Point lies in: Quadrant I

# %%
# @title Loop


#1-Sum of Numbers


n = int(input("Enter a positive integer: "))
sum_of_numbers = sum(range(1, n+1))
print("Sum of numbers from 1 to", n, "is", sum_of_numbers)


#2-Factorial:

n = int(input("Enter a non-negative integer: "))
factorial = 1
for i in range(1, n+1):
    factorial *= i
print("Factorial of", n, "is", factorial)


#3-Reverse a Number


num = int(input("Enter an integer: "))
reverse = 0
while num != 0:
    reverse = reverse * 10 + num % 10
    num //= 10
print("Reverse of the number is", reverse)

#4-Count Digits


num = int(input("Enter an integer: "))
count = 0
while num != 0:
    count += 1
    num //= 10
print("Number of digits:", count)


#5-Power


x = float(input("Enter the base number (x): "))
n = int(input("Enter the exponent (n): "))
result = 1
for _ in range(n):
    result *= x
print("Result:", result)
# Out:
# Enter a positive integer: 12
# Sum of numbers from 1 to 12 is 78
# Enter a non-negative integer: 32
# Factorial of 32 is 263130836933693530167218012160000000
# Enter an integer: 12
# Reverse of the number is 21
# Enter an integer: 321
# Number of digits: 3
# Enter the base number (x): 23
# Enter the exponent (n): 3
# Result: 12167.0
