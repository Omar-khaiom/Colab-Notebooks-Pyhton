# %%
#Problem 1: Validity
str='str1'
str2="str1"
str3='"str3"'
print(bool(0), bool(3.14159), bool(-3), bool(1.0+1j))
# Out:
# False True True True

# %%
#Problem 2: Enter the Address
print('Enter your address')
address=input()
print(f'Your Address is:{address}')
# Out:
# Enter your address
# Uttara,Dhaka
# Your Address is:Uttara,Dhaka

# %%
#Problem 3: Print your information
name = input('Enter your name')
address = input('Enter your address')
email = input('Enter your email')
phone = input('Enter your phone')
print('\nYour information is as follows')
print("Name:", name)
print("Address:", address)
print("Email:", email)
print("Phone:", phone)
# Out:
# Enter your nameRahat
# Enter your addressuttara
# Enter your emailasdasd
# Enter your phone01239
#
# Your information is as follows
# Name: Rahat
# Address: uttara
# Email: asdasd
# Phone: 01239

# %%
#Problem 4: Calculate the power


x = float(input('Enter the value of x'))
y = float(input('Enter the value of y'))

calculate_value = 1 / y
result = x** calculate_value
print(f"The result of {x}^(1/{y}) is: {result}")
# Out:
# Enter the value of x12
# Enter the value of y32
# The result of 12.0^(1/32.0) is: 1.0807479338676478

# %%
#Problem 5: Simple Calculator
n1 = float(input('Enter the first number'))
n2 = float(input('Enter the secend number'))
addition = n1+n2
subtraction = n1-n2
division = n1/n2
multiplication = n1*n2
print(f'\nAddition ({n1}+{n2}) = {addition} ')
print(f'\nSubtraction ({n1}-{n2}) = {subtraction}')
print(f'\nDivision ({n1}/{n2}) = {division}')
print(f'\nMultiplication ({n1}*{n2}) = {multiplication}')
# Out:
# Enter the first number12
# Enter the secend number4
#
# Addition (12.0+4.0) = 16.0
#
# Subtraction (12.0-4.0) = 8.0
#
# Division (12.0/4.0) = 3.0
#
# Multiplication (12.0*4.0) = 48.0

# %%
#Problem 6: A Simple Line Equation
slope = float(input("Enter slope (m): "))
intercept = float(input("Enter intercept (b): "))
x = float(input("Enter x: "))
y = slope * x + intercept
print("f(", x, ") = ", y)
# Out:
# Enter slope (m): 2
# Enter intercept (b): 4
# Enter x: 5
# f( 5.0 ) =  14.0

# %%
#Problem 7: Play with the numbers

# Take 5 numbers as input
num1 = float(input("Enter number 1: "))
num2 = float(input("Enter number 2: "))
num3 = float(input("Enter number 3: "))
num4 = float(input("Enter number 4: "))
num5 = float(input("Enter number 5: "))

total_sum = num1 + num2 + num3 + num4 + num5
average = total_sum / 5
quotient = num1 / num5
product_division = (num2 * num4) / num3

greater_than_5 = num1 > 5 or num2 > 5 or num3 > 5 or num4 > 5 or num5 > 5
divisible_by_13 = num1 % 13 == 0 and num2 % 13 == 0 and num3 % 13 == 0 and num4 % 13 == 0 and num5 % 13 == 0
equal_to_42 = num1 == 42 or num2 == 42 or num3 == 42 or num4 == 42 or num5 == 42
print("a. Sum of the numbers:", total_sum)
print("b. Average of the numbers:", average)
print("c. Quotient of the first number divided by the fifth number:", quotient)
print("d. Product of the second number with the fourth number divided by the third number:", product_division)
print("e. (True/False) If any of the numbers are greater than 5:", greater_than_5)
print("f. (True/False) If all of the numbers are divisible by 13:", divisible_by_13)
print("g. (True/False) If any of the numbers is equal to 42:", equal_to_42)
# Out:
# Enter number 1: 12
# Enter number 2: 12
# Enter number 3: 23
# Enter number 4: 4
# Enter number 5: 12
# a. Sum of the numbers: 63.0
# b. Average of the numbers: 12.6
# c. Quotient of the first number divided by the fifth number: 1.0
# d. Product of the second number with the fourth number divided by the third number: 2.0869565217391304
# e. (True/False) If any of the numbers are greater than 5: True
# f. (True/False) If all of the numbers are divisible by 13: False
# g. (True/False) If any of the numbers is equal to 42: False

# %%
#Problem 8: Pizza Party with Friends 😇

slices = int(input("Enter the number of slices: "))
total_price = float(input("Enter the total price of the pizza: "))
your_slices = int(input("Enter the number of slices you ate: "))

friends_slices = []
for i in range(5):
    friend_slices = int(input(f"Enter the number of slices friend {i+1} ate: "))
    friends_slices.append(friend_slices)

total_slices_eaten = your_slices + sum(friends_slices)
price_per_slice = total_price / slices

print("\nAmount each should pay:")
print("You:", your_slices * price_per_slice)

friend_number = 1
for slices in friends_slices:
    friend_payment = slices * price_per_slice
    print("Friend", friend_number, ":", friend_payment)
    friend_number += 1
# Out:
# Enter the number of slices: 12
# Enter the total price of the pizza: 550
# Enter the number of slices you ate: 3
# Enter the number of slices friend 1 ate: 2
# Enter the number of slices friend 2 ate: 3
# Enter the number of slices friend 3 ate: 1
# Enter the number of slices friend 4 ate: 2
# Enter the number of slices friend 5 ate: 1
#
# Amount each should pay:
# You: 137.5
# Friend 1 : 91.66666666666667
# Friend 2 : 137.5
# Friend 3 : 45.833333333333336
# Friend 4 : 91.66666666666667
# Friend 5 : 45.833333333333336

# %%
#Problem 9: Distance in 2D Space
def calculate_distance(a, b, c, d):
    distance = ((c - a) ** 2 + (d - b) ** 2) ** 0.5
    return distance

a = float(input("Enter the x-coordinate of the first point: "))
b = float(input("Enter the y-coordinate of the first point: "))
c = float(input("Enter the x-coordinate of the second point: "))
d = float(input("Enter the y-coordinate of the second point: "))
distance = calculate_distance(a, b, c, d)
print("Distance:", "%.4f" % distance)
# Out:
# Enter the x-coordinate of the first point: 12
# Enter the y-coordinate of the first point: 23
# Enter the x-coordinate of the second point: 6
# Enter the y-coordinate of the second point: 4
# Distance: 19.9249

# %%
#Problem 10: Complex Number Multipication
def multiply_complex(x, y, u, v):
    real_part = x * u - y * v
    imaginary_part = x * v + y * u
    return real_part, imaginary_part
x = float(input("Enter the real part of the first complex number: "))
y = float(input("Enter the imaginary part of the first complex number: "))
u = float(input("Enter the real part of the second complex number: "))
v = float(input("Enter the imaginary part of the second complex number: "))
result_real, result_imaginary = multiply_complex(x, y, u, v)
print("The multiplication of the two complex numbers is:", result_real, "+", result_imaginary, "i")
# Out:
# Enter the real part of the first complex number: 3
# Enter the imaginary part of the first complex number: 2
# Enter the real part of the second complex number: 1
# Enter the imaginary part of the second complex number: 4
# The multiplication of the two complex numbers is: -5.0 + 14.0 i

# %%
#Problem 11: Library Assistant
hours_per_week = int(input("Enter the number of hours you will work per week: "))
earnings_per_hour = int(input("Enter the amount you earn per hour: BDT. "))
monthly_earning = hours_per_week * earnings_per_hour * 4
yearly_earning = monthly_earning * 12
tuition_fees_per_year = yearly_earning * 0.20
monthly_earning_after_deduction = monthly_earning - (tuition_fees_per_year / 12)
print("Monthly earning: BDT.", monthly_earning)
print("Monthly earning after deduction: BDT.", monthly_earning_after_deduction)
print("Yearly earning: BDT.", yearly_earning)
print("Amount paid as tuition fees per year: BDT.", tuition_fees_per_year)
# Out:
# Enter the number of hours you will work per week: 20
# Enter the amount you earn per hour: BDT. 50
# Monthly earning: BDT. 4000
# Monthly earning after deduction: BDT. 3200.0
# Yearly earning: BDT. 48000
# Amount paid as tuition fees per year: BDT. 9600.0

# %%
# @title Problem 12: Find the Errors

# %%
# Find the errors in the following Python code: (write it down in a text cell.)
radius = 5
pi = 3.14
area = pi * radius**2
# Following statement will display the area: 78.5
print('Area is:', area)

          #No errors
# Out:
# Area is: 78.5

# %%
# Find the errors in the following Python code:(write it down in a text cell.)
price = 25.99
quantity = 10
total_cost = price * quantity
# Following statement will display the total cost: The total cost is $259.9
print('The total cost is $' , total_cost)
# Out:
# The total cost is $ 259.9

# %%
# Find the errors in the following Python code:(write it down in a text cell.)
a = 7
b = 2
remainder = a%b
# Following statement will display the remainder: 1
print('remainder is:', remainder)
# Out:
# remainder is: 1
