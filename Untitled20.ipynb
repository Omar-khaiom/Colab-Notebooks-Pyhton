# %%
x = int(input("enter any number "))
y = int(input("enter a secend number "))
z = x + y
print(z)
# Out:
# enter any number 5
# enter a secend number 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-52b99a70d9f9> in <cell line: 4>()
#       2 y = int(input("enter a secend number "))
#       3 z = x + y
# ----> 4 print(z)
#
# TypeError: 'int' object is not callable
