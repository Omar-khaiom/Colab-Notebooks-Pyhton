# %%
#my name:
#Studint id
#email
#section
#course id:
a="omar khaiom"
b="2230594"
c="atifo5780@gmail.com"
d="section 9"
e="cse101"
print(a,b,c,d,e)
print(a)
print(b)
print(c)
print(d)
print(e)
information={
  "Name " : "Rahat",
  "student id":"2230594",
  "email":"atifo4780@gmail.com",
  "section" :"9",
  "course id " :"cse101"
}

i=information
my_name="rahat"
s_id="2230594"
email="rahat3580@gmail.com"
sec="9"
c_id="cse101"
print(f"my name is",my_name)
print(f"my studint id is",s_id)
print(f"my emai is",email)
print(f"my sec is",sec)
print(f"my course id is",c_id)
print(i)


given=input("what is your age")
if num<18:
  `return False
# Out:
#   File "<ipython-input-18-c7fdb0750d1d>", line 41
#     `return False
#     ^
# SyntaxError: invalid syntax

# %%
print(f"my name is")
# Out:
# my name is
