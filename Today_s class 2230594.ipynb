# %%
# Problem : Write a function that takes a
#number as input and prints if the number is a
#multiple of 2 or 5 or both or none.
def is_multiple(n):
#calculations
    if n % 2 == 0 and n % 5 == 0:
        print('Multiple of 2 and 5')
    elif n % 2 == 0:
        print('Multiple of 2')
    elif n % 5 ==0:
        print('Multiple of 5')
    else:
        print ('None')

#checking if the number is a multiple

is_multiple(10)
is_multiple(15)
is_multiple(22)
is_multiple(11)
# Out:
# Multiple of 2 and 5
# Multiple of 5
# Multiple of 2
# None

# %%
# Problem : Write a function that takes an alphabet as input and prints
#whether the alphabet is Uppercase or Lowercase or it’s an invalid input
def check_case(alphabet):
#checking the case of the input
    if 'a' <= alphabet <= 'z' or 'A' <= alphabet<= 'Z':
        if alphabet in 'qwertyuioplkjhgfdsazxcvbnm':
         print('lower case letter')
        else:
            print('Upper case letter')
    else:
        print('Invalid Input')
#Check the alphabet case
check_case('A')
check_case('f')
#checking the other else clause
check_case('6')
# Out:
# Upper case letter
# lower case letter
# Invalid Input
